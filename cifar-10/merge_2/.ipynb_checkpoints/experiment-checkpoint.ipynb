# %%
import logistic_sgd
import mlp
reload(mlp)
reload(logistic_sgd)
# Out:
# <module 'logistic_sgd' from '/home/davidheryanto/Git/incremental-kd/logistic_sgd.pyc'>

# %%
import os, cPickle, operator, time, random
from collections import defaultdict, OrderedDict
import numpy as np

import theano
import theano.tensor as T
from theano.ifelse import ifelse

from copy import deepcopy

from logistic_sgd import *
from mlp import *

# %%
def save_params(file_name, model):
    with open(file_name, 'wb') as out_file:
        cPickle.dump(model.params, out_file)

def set_params(file_name, model):
    with open(file_name, 'rb') as in_file:
        new_params = cPickle.load(in_file)
    for current_p, new_p in zip(model.params, new_params):
        current_p.set_value(new_p.eval())

def reset_params(model, file_name=None):
    if file_name == None:
        file_name = 'model_initial_params.pkl'
    
    print('Before reset:')
    for p in model.params[:2]:
        print(p[0].eval()),
        
    with open(file_name, 'rb') as in_file:
        initial_params = cPickle.load(in_file)
        
    for initial, current in zip(initial_params, model.params):
        current.set_value(initial.eval())
        
    print('\nAfter reset')
    for p in model.params[:2]:
        print(p[0].eval()),
    print('\n')

def save_valid_error(file_name, valid_error):
    with open(file_name, 'wb') as out_file:
        cPickle.dump(valid_error, out_file)

def get_confidence_for_minibatch(index):
    start = index * batch_size
    end = (index + 1) * batch_size
    return np.mean(np.max(get_p_y_given_x(X[start:end]), axis=1))

def should_continue_training(min_valid_error_epoch, epoch_num, diff=25, min_epoch=100):
    if epoch_num < min_epoch:
        return True
    else:
        return False
#         return epoch_num - min_valid_error_epoch < diff

# %%
# Load original image for visualization purpose
from pylearn2.datasets.cifar10 import CIFAR10
train_set = CIFAR10(which_set='train', start=0, stop=45000)
# Out:
# loading file /home/david/Dropbox/Projects/data/cifar10/cifar-10-batches-py/data_batch_1
# loading file /home/david/Dropbox/Projects/data/cifar10/cifar-10-batches-py/data_batch_2
# loading file /home/david/Dropbox/Projects/data/cifar10/cifar-10-batches-py/data_batch_3
# loading file /home/david/Dropbox/Projects/data/cifar10/cifar-10-batches-py/data_batch_4
# loading file /home/david/Dropbox/Projects/data/cifar10/cifar-10-batches-py/data_batch_5
# loading file /home/david/Dropbox/Projects/data/cifar10/cifar-10-batches-py/test_batch

# %%
pylab.rcParams['figure.figsize'] = 12, 12
for i, img in enumerate(train_set.X[:100]):
    plt.subplot(10, 10, i+1)
    plt.imshow(np.rot90(img.reshape(32,32,3,order='F')[::-1,:,::-1], k=3))
    plt.title(train_set.label_names[train_set.y[i]])
    plt.gca().axes.get_xaxis().set_ticks([])
    plt.gca().axes.get_yaxis().set_ticks([])

# %%
learning_rate = 0.050
L1_reg = 0
L2_reg = 1e-4
batch_size = 100

# nkerns = (150, 75)  # default: (20, 50)
nkerns = (80, 40)
n_in = 500
temperature = 3

dropout_ps = [0.1, 0.25, 0.25, 0.5]

# %%
# Use cifar10_david / cifar10_davidheryanto
cifar_path = os.path.join(
    os.getenv('PYLEARN2_DATA_PATH'), 'cifar10'
)
datasets = load_cifar10(cifar_path)

train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]

# compute number of minibatches for training, validation and testing
n_train_batches = train_set_x.get_value(borrow=True).shape[0]
n_valid_batches = valid_set_x.get_value(borrow=True).shape[0]
n_test_batches = test_set_x.get_value(borrow=True).shape[0]
n_train_batches /= batch_size
n_valid_batches /= batch_size
n_test_batches /= batch_size

index = T.lscalar()  # index to a [mini]batch

x = T.matrix('x')  
y = T.ivector('y')

# %% [markdown]
# **Train model_1**

# %%
print '... building model_1'

rng = numpy.random.RandomState(23455)
random.seed(51665)

model_1 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
    temperature=temperature,
    dropout_ps=dropout_ps
)

cost_model_1 = model_1.negative_log_likelihood(y)

test_model_1 = theano.function(
    inputs=[index],
    outputs=model_1.errors(y),
    givens={
        x: test_set_x[index * batch_size: (index + 1) * batch_size],
        y: test_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

validate_model_1 = theano.function(
    inputs=[index],
    outputs=model_1.errors(y),
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

grads_model_1 = [T.grad(cost_model_1, param) for param in model_1.params]

updates_model_1 = [
    (param, param - learning_rate * grad)
    for param, grad in zip(model_1.params, grads_model_1)
]

train_model_1 = theano.function(
    inputs=[index],
    outputs=cost_model_1,
    updates=updates_model_1,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)
# Out:
# ... building model_1

# %%
valid_error = []
min_valid_error = np.inf
min_valid_error_epoch = 0
minibatch_indexes = range(int(n_train_batches / 2))
epoch_num = 0
print('|Epoch|Valid error|Min (Epoch)|Sec/epoch')
print('|-:|-:|-:|-:')

while should_continue_training(min_valid_error_epoch, epoch_num):
    epoch_num += 1
    start_time = time.time()
    random.shuffle(minibatch_indexes)
    
    for minibatch_index in minibatch_indexes:
        train_model_1(minibatch_index)
        
    valid_loss = np.mean([validate_model_1(i) for i in xrange(n_valid_batches)])
    valid_error.append(valid_loss)
    
    if valid_loss < min_valid_error:
        min_valid_error = valid_loss
        min_valid_error_epoch = epoch_num
        save_params('model_1_best.pkl', model_1)
    
    print('|{:>4}|{:.4f}|{:.4f} ({:>4})|{:>4.1f}').format(
        epoch_num, valid_loss, min_valid_error, min_valid_error_epoch,
        time.time() - start_time
    )
    
# Finish training
save_valid_error('model_1_valid_error.pkl', valid_error)

set_params('./model_1_best.pkl', model_1)
test_loss = np.mean([test_model_1(i) for i in xrange(n_test_batches)])
print('Test error: {}'.format(test_loss))

pylab.rcParams['figure.figsize'] = 8, 6
plt.plot(valid_error)
plt.ylabel('valid error')
plt.xlabel('epoch #')
plt.title('model_1')
# Out:
# |Epoch|Valid error|Min (Epoch)|Sec/epoch
# |-:|-:|-:|-:
# |   1|0.7646|0.7646 (   1)|392.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-7d70ab13eb49> in <module>()
#      13
#      14     for minibatch_index in minibatch_indexes:
# ---> 15         train_model_1(minibatch_index)
#      16
#      17     valid_loss = np.mean([validate_model_1(i) for i in xrange(n_valid_batches)])
#
# /home/davidheryanto/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %% [markdown]
# **Train model_2**

# %%
print '... building model_2'

rng = numpy.random.RandomState(23455)
random.seed(51665)

model_2 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
    temperature=temperature
)

cost_model_2 = (
    model_2.negative_log_likelihood(y) + \
    L1_reg * model_2.L1 + \
    L2_reg * model_2.L2_sqr
)

test_model_2 = theano.function(
    inputs=[index],
    outputs=model_2.errors(y),
    givens={
        x: test_set_x[index * batch_size: (index + 1) * batch_size],
        y: test_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

validate_model_2 = theano.function(
    inputs=[index],
    outputs=model_2.errors(y),
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

grads_model_2 = [T.grad(cost_model_2, param) for param in model_2.params]

updates_model_2 = [
    (param, param - learning_rate * grad)
    for param, grad in zip(model_2.params, grads_model_2)
]

train_model_2 = theano.function(
    inputs=[index],
    outputs=cost_model_2,
    updates=updates_model_2,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

get_p_y_given_x = theano.function([x], model_2.p_y_given_x)
# Out:
# ... building model_2

# %%
valid_error = []
min_valid_error = np.inf
min_valid_error_epoch = 0
minibatch_indexes = range(int(n_train_batches / 2), n_train_batches)
epoch_num = 0
print('|Epoch|Valid error|Min (Epoch)|Sec/epoch')
print('|-:|-:|-:|-:')

while should_continue_training(min_valid_error_epoch, epoch_num):
    epoch_num += 1
    start_time = time.time()
    random.shuffle(minibatch_indexes)
    
    for minibatch_index in minibatch_indexes:
        train_model_2(minibatch_index)
        
    valid_loss = np.mean([validate_model_2(i) for i in xrange(n_valid_batches)])
    valid_error.append(valid_loss)
    
    if valid_loss < min_valid_error:
        min_valid_error = valid_loss
        min_valid_error_epoch = epoch_num
        save_params('model_2_best.pkl', model_2)
    
    print('|{:>4}|{:.4f}|{:.4f} ({:>4})|{:>4.1f}').format(
        epoch_num, valid_loss, min_valid_error, min_valid_error_epoch,
        time.time() - start_time
    )
    
# Finish training
save_valid_error('model_2_valid_error.pkl', valid_error)

set_params('./model_2_best.pkl', model_2)
test_loss = np.mean([test_model_2(i) for i in xrange(n_test_batches)])
print('Test error: {}'.format(test_loss))

pylab.rcParams['figure.figsize'] = 8, 6
plt.plot(valid_error)
plt.ylabel('valid error')
plt.xlabel('epoch #')
plt.title('model_2')
# Out:
# |Epoch|Valid error|Min (Epoch)|Sec/epoch
# |-:|-:|-:|-:
# |   1|0.5984|0.5984 (   1)|14.2
# |   2|0.4750|0.4750 (   2)|14.3
# |   3|0.4188|0.4188 (   3)|14.2
# |   4|0.4010|0.4010 (   4)|14.2
# |   5|0.3774|0.3774 (   5)|14.2
# |   6|0.3864|0.3774 (   5)|14.0
# |   7|0.3572|0.3572 (   7)|14.3
# |   8|0.3618|0.3572 (   7)|14.0
# |   9|0.3488|0.3488 (   9)|14.3
# |  10|0.3372|0.3372 (  10)|14.2
# |  11|0.3468|0.3372 (  10)|14.1
# |  12|0.3430|0.3372 (  10)|14.0
# |  13|0.3370|0.3370 (  13)|14.3
# |  14|0.3460|0.3370 (  13)|14.0
# |  15|0.3454|0.3370 (  13)|14.0
# |  16|0.3494|0.3370 (  13)|14.1
# |  17|0.3452|0.3370 (  13)|14.1
# |  18|0.3474|0.3370 (  13)|14.1
# |  19|0.3542|0.3370 (  13)|14.0
# |  20|0.3482|0.3370 (  13)|14.0
# |  21|0.3504|0.3370 (  13)|14.0
# |  22|0.3494|0.3370 (  13)|14.2
# |  23|0.3490|0.3370 (  13)|14.1
# |  24|0.3484|0.3370 (  13)|14.1
# |  25|0.3446|0.3370 (  13)|14.2
# |  26|0.3450|0.3370 (  13)|14.1
# |  27|0.3468|0.3370 (  13)|14.2
# |  28|0.3476|0.3370 (  13)|14.2
# |  29|0.3472|0.3370 (  13)|14.3
# |  30|0.3480|0.3370 (  13)|14.2
# |  31|0.3446|0.3370 (  13)|14.0
# |  32|0.3470|0.3370 (  13)|14.0
# |  33|0.3470|0.3370 (  13)|14.1
# |  34|0.3480|0.3370 (  13)|14.0
# |  35|0.3466|0.3370 (  13)|14.0
# |  36|0.3474|0.3370 (  13)|14.0
# |  37|0.3466|0.3370 (  13)|14.2
# |  38|0.3476|0.3370 (  13)|14.0
# |  39|0.3466|0.3370 (  13)|14.1
# |  40|0.3474|0.3370 (  13)|14.1
# |  41|0.3466|0.3370 (  13)|14.0
# |  42|0.3476|0.3370 (  13)|14.0
# |  43|0.3476|0.3370 (  13)|14.1
# |  44|0.3456|0.3370 (  13)|14.2
# |  45|0.3468|0.3370 (  13)|14.1
# |  46|0.3460|0.3370 (  13)|14.4
# |  47|0.3454|0.3370 (  13)|14.2
# |  48|0.3454|0.3370 (  13)|14.1
# |  49|0.3476|0.3370 (  13)|14.3
# |  50|0.3444|0.3370 (  13)|14.2
# |  51|0.3472|0.3370 (  13)|14.2
# |  52|0.3472|0.3370 (  13)|14.1
# |  53|0.3468|0.3370 (  13)|14.1
# |  54|0.3488|0.3370 (  13)|14.1
# |  55|0.3468|0.3370 (  13)|14.0
# |  56|0.3470|0.3370 (  13)|13.9
# |  57|0.3482|0.3370 (  13)|14.1
# |  58|0.3464|0.3370 (  13)|14.2
# |  59|0.3468|0.3370 (  13)|14.0
# |  60|0.3454|0.3370 (  13)|14.0
# |  61|0.3486|0.3370 (  13)|14.0
# |  62|0.3472|0.3370 (  13)|14.0
# |  63|0.3444|0.3370 (  13)|14.0
# |  64|0.3464|0.3370 (  13)|13.9
# |  65|0.3490|0.3370 (  13)|14.0
# |  66|0.3472|0.3370 (  13)|14.0
# |  67|0.3470|0.3370 (  13)|14.0
# |  68|0.3478|0.3370 (  13)|14.1
# |  69|0.3462|0.3370 (  13)|14.0
# |  70|0.3474|0.3370 (  13)|14.0
# |  71|0.3458|0.3370 (  13)|13.3
# |  72|0.3480|0.3370 (  13)|11.2
# |  73|0.3490|0.3370 (  13)|11.3
# |  74|0.3480|0.3370 (  13)|11.7
# |  75|0.3488|0.3370 (  13)|11.5
# |  76|0.3494|0.3370 (  13)|11.4
# |  77|0.3480|0.3370 (  13)|11.3
# |  78|0.3462|0.3370 (  13)|11.3
# |  79|0.3478|0.3370 (  13)|11.4
# |  80|0.3482|0.3370 (  13)|11.4
# |  81|0.3476|0.3370 (  13)|11.3
# |  82|0.3494|0.3370 (  13)|11.3
# |  83|0.3490|0.3370 (  13)|11.2
# |  84|0.3486|0.3370 (  13)|11.2
# |  85|0.3486|0.3370 (  13)|11.3
# |  86|0.3466|0.3370 (  13)|11.3
# |  87|0.3456|0.3370 (  13)|11.2
# |  88|0.3468|0.3370 (  13)|11.3
# |  89|0.3474|0.3370 (  13)|11.3
# |  90|0.3504|0.3370 (  13)|11.2
# |  91|0.3466|0.3370 (  13)|11.2
# |  92|0.3472|0.3370 (  13)|11.2
# |  93|0.3486|0.3370 (  13)|11.2
# |  94|0.3488|0.3370 (  13)|11.2
# |  95|0.3512|0.3370 (  13)|11.2
# |  96|0.3466|0.3370 (  13)|11.2
# |  97|0.3476|0.3370 (  13)|11.3
# |  98|0.3492|0.3370 (  13)|11.2
# |  99|0.3496|0.3370 (  13)|11.2
# | 100|0.3474|0.3370 (  13)|11.2
# Test error: 0.3568

# %% [markdown]
# **Base 1: Ideal setting, use all examples (45,000)**

# %%
print '... building model_base_1'

rng = numpy.random.RandomState(23455)
random.seed(51665)

model_base_1 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
    temperature=temperature
)

cost_model_base_1 = (
    model_base_1.negative_log_likelihood(y) + \
    L1_reg * model_base_1.L1 + \
    L2_reg * model_base_1.L2_sqr
)

test_model_base_1 = theano.function(
    inputs=[index],
    outputs=model_base_1.errors(y),
    givens={
        x: test_set_x[index * batch_size: (index + 1) * batch_size],
        y: test_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

validate_model_base_1 = theano.function(
    inputs=[index],
    outputs=model_base_1.errors(y),
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

grads_model_base_1 = [T.grad(cost_model_base_1, param) for param in model_base_1.params]

updates_model_base_1 = [
    (param, param - learning_rate * grad)
    for param, grad in zip(model_base_1.params, grads_model_base_1)
]

train_model_base_1 = theano.function(
    inputs=[index],
    outputs=cost_model_base_1,
    updates=updates_model_base_1,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)
# Out:
# ... building model_base_1

# %%
valid_error = []
min_valid_error = np.inf
min_valid_error_epoch = 0
minibatch_indexes = range(n_train_batches)
epoch_num = 0
print('|Epoch|Valid error|Min (Epoch)|Sec/epoch')
print('|-:|-:|-:|-:')

while should_continue_training(min_valid_error_epoch, epoch_num):
    epoch_num += 1
    start_time = time.time()
    random.shuffle(minibatch_indexes)
    
    for minibatch_index in minibatch_indexes:
        train_model_base_1(minibatch_index)
        
    valid_loss = np.mean([validate_model_base_1(i) for i in xrange(n_valid_batches)])
    valid_error.append(valid_loss)
    
    if valid_loss < min_valid_error:
        min_valid_error = valid_loss
        min_valid_error_epoch = epoch_num
        save_params('model_base_1_best.pkl', model_base_1)
    
    print('|{:>4}|{:.4f}|{:.4f} ({:>4})|{:>4.1f}').format(
        epoch_num, valid_loss, min_valid_error, min_valid_error_epoch,
        time.time() - start_time
    )
    
# Finish training
save_valid_error('model_base_1_valid_error.pkl', valid_error)

set_params('./model_base_1_best.pkl', model_base_1)
test_loss = np.mean([test_model_base_1(i) for i in xrange(n_test_batches)])
print('Test error: {}'.format(test_loss))

pylab.rcParams['figure.figsize'] = 8, 6
plt.plot(valid_error)
plt.ylabel('valid error')
plt.xlabel('epoch #')
plt.title('model_base_1')
# Out:
# |Epoch|Valid error|Min (Epoch)|Sec/epoch
# |-:|-:|-:|-:
# |   1|0.4730|0.4730 (   1)|21.7
# |   2|0.4140|0.4140 (   2)|21.5
# |   3|0.3512|0.3512 (   3)|21.5
# |   4|0.3400|0.3400 (   4)|21.5
# |   5|0.3182|0.3182 (   5)|21.5
# |   6|0.3110|0.3110 (   6)|21.4
# |   7|0.3048|0.3048 (   7)|21.4
# |   8|0.2976|0.2976 (   8)|21.4
# |   9|0.3056|0.2976 (   8)|21.3
# |  10|0.2930|0.2930 (  10)|21.4
# |  11|0.2922|0.2922 (  11)|21.4
# |  12|0.2898|0.2898 (  12)|21.4
# |  13|0.2932|0.2898 (  12)|21.3
# |  14|0.2900|0.2898 (  12)|21.3
# |  15|0.3070|0.2898 (  12)|21.3
# |  16|0.2968|0.2898 (  12)|21.3
# |  17|0.2966|0.2898 (  12)|21.3
# |  18|0.3052|0.2898 (  12)|21.3
# |  19|0.3064|0.2898 (  12)|21.3
# |  20|0.2992|0.2898 (  12)|21.3
# |  21|0.3008|0.2898 (  12)|21.3
# |  22|0.3024|0.2898 (  12)|21.3
# |  23|0.3048|0.2898 (  12)|21.3
# |  24|0.2996|0.2898 (  12)|21.3
# |  25|0.3000|0.2898 (  12)|21.3
# |  26|0.3004|0.2898 (  12)|21.3
# |  27|0.3012|0.2898 (  12)|21.4
# |  28|0.3020|0.2898 (  12)|21.3
# |  29|0.3020|0.2898 (  12)|21.3
# |  30|0.3002|0.2898 (  12)|21.3
# |  31|0.2980|0.2898 (  12)|21.3
# |  32|0.2988|0.2898 (  12)|21.3
# |  33|0.3016|0.2898 (  12)|21.3
# |  34|0.2998|0.2898 (  12)|21.3
# |  35|0.2968|0.2898 (  12)|21.3
# |  36|0.2992|0.2898 (  12)|21.3
# |  37|0.2968|0.2898 (  12)|21.3
# |  38|0.2988|0.2898 (  12)|21.3
# |  39|0.2996|0.2898 (  12)|21.3
# |  40|0.2994|0.2898 (  12)|21.3
# |  41|0.3030|0.2898 (  12)|21.3
# |  42|0.2992|0.2898 (  12)|21.3
# |  43|0.3002|0.2898 (  12)|21.3
# |  44|0.2988|0.2898 (  12)|21.3
# |  45|0.3014|0.2898 (  12)|21.3
# |  46|0.2998|0.2898 (  12)|21.3
# |  47|0.2984|0.2898 (  12)|21.3
# |  48|0.2974|0.2898 (  12)|21.3
# |  49|0.2980|0.2898 (  12)|21.3
# |  50|0.2988|0.2898 (  12)|21.3
# |  51|0.2990|0.2898 (  12)|21.3
# |  52|0.3002|0.2898 (  12)|23.9
# |  53|0.2996|0.2898 (  12)|26.4
# |  54|0.3002|0.2898 (  12)|26.3
# |  55|0.2994|0.2898 (  12)|26.5
# |  56|0.3002|0.2898 (  12)|26.4
# |  57|0.2990|0.2898 (  12)|26.4
# |  58|0.3006|0.2898 (  12)|26.4
# |  59|0.3002|0.2898 (  12)|26.4
# |  60|0.2990|0.2898 (  12)|26.5
# |  61|0.2994|0.2898 (  12)|26.4
# |  62|0.3000|0.2898 (  12)|26.4
# |  63|0.2992|0.2898 (  12)|26.4
# |  64|0.2994|0.2898 (  12)|26.4
# |  65|0.3006|0.2898 (  12)|26.4
# |  66|0.2986|0.2898 (  12)|26.4
# |  67|0.3004|0.2898 (  12)|26.4
# |  68|0.3014|0.2898 (  12)|26.4
# |  69|0.2998|0.2898 (  12)|26.5
# |  70|0.2992|0.2898 (  12)|26.4
# |  71|0.2978|0.2898 (  12)|26.5
# |  72|0.2988|0.2898 (  12)|26.4
# |  73|0.2998|0.2898 (  12)|26.5
# |  74|0.2998|0.2898 (  12)|26.4
# |  75|0.3008|0.2898 (  12)|26.5
# |  76|0.3010|0.2898 (  12)|26.4
# |  77|0.3002|0.2898 (  12)|26.4
# |  78|0.2984|0.2898 (  12)|26.4
# |  79|0.3002|0.2898 (  12)|26.5
# |  80|0.3022|0.2898 (  12)|26.4
# |  81|0.2994|0.2898 (  12)|26.4
# |  82|0.3028|0.2898 (  12)|26.8
# |  83|0.3002|0.2898 (  12)|26.4
# |  84|0.3000|0.2898 (  12)|26.4
# |  85|0.3016|0.2898 (  12)|26.5
# |  86|0.3008|0.2898 (  12)|26.5
# |  87|0.2994|0.2898 (  12)|26.5
# |  88|0.3008|0.2898 (  12)|23.0
# |  89|0.3016|0.2898 (  12)|21.4
# |  90|0.2986|0.2898 (  12)|21.3
# |  91|0.2996|0.2898 (  12)|21.3
# |  92|0.3026|0.2898 (  12)|21.3
# |  93|0.3008|0.2898 (  12)|21.3
# |  94|0.3040|0.2898 (  12)|21.3
# |  95|0.3032|0.2898 (  12)|21.3
# |  96|0.3030|0.2898 (  12)|21.3
# |  97|0.3012|0.2898 (  12)|21.3
# |  98|0.3034|0.2898 (  12)|21.4
# |  99|0.3038|0.2898 (  12)|21.3
# | 100|0.3052|0.2898 (  12)|21.3
# Test error: 0.3007

# %% [markdown]
# **Base 2: Train a new model, init with param of model_1_best**

# %%
def set_avg_params(paths, model, layer_start=None, layer_end=None):
    if layer_start is None:
        layer_start = 0
    if layer_end is None:
        layer_end = len(model.params)
    
    params = []
    
    for path in paths:
        with open(path, 'rb') as in_file:
            params_loaded = cPickle.load(in_file)
            params.append(params_loaded[layer_start:layer_end])
    
    new_params = []
    for params_tuple in zip(*params):
        total = params_tuple[0].get_value()
        for param in params_tuple[1:]:
            total += param.get_value()
        avg = total / float(len(params))
        new_params.append(avg)
    
    for current_param, new_param in zip(model.params[layer_start:layer_end], new_params):
        # print(current_param.shape.eval(), new_param.shape)
        current_param.set_value(new_param)

# %%
print '... building model_base_2'

rng = numpy.random.RandomState(23455)
random.seed(51665)

model_base_2 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
    temperature=temperature
)
set_avg_params(['model_1_best.pkl'], model_base_2, layer_start=4)

cost_model_base_2 = (
    model_base_2.negative_log_likelihood(y) + \
    L1_reg * model_base_2.L1 + \
    L2_reg * model_base_2.L2_sqr
)

test_model_base_2 = theano.function(
    inputs=[index],
    outputs=model_base_2.errors(y),
    givens={
        x: test_set_x[index * batch_size: (index + 1) * batch_size],
        y: test_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

validate_model_base_2 = theano.function(
    inputs=[index],
    outputs=model_base_2.errors(y),
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

grads_model_base_2 = [T.grad(cost_model_base_2, param) for param in model_base_2.params]

updates_model_base_2 = [
    (param, param - learning_rate * grad)
    for param, grad in zip(model_base_2.params, grads_model_base_2)
]

train_model_base_2 = theano.function(
    inputs=[index],
    outputs=cost_model_base_2,
    updates=updates_model_base_2,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)
# Out:
# ... building model_base_2

# %%
valid_error = []
min_valid_error = np.inf
min_valid_error_epoch = 0
minibatch_indexes = range(int(n_train_batches * 0.50), n_train_batches)
epoch_num = 0
print('|Epoch|Valid error|Min (Epoch)|Sec/epoch')
print('|-:|-:|-:|-:')

while should_continue_training(min_valid_error_epoch, epoch_num):
    epoch_num += 1
    start_time = time.time()
    random.shuffle(minibatch_indexes)
    
    for minibatch_index in minibatch_indexes:
        train_model_base_2(minibatch_index)
        
    valid_loss = np.mean([validate_model_base_2(i) for i in xrange(n_valid_batches)])
    valid_error.append(valid_loss)
    
    if valid_loss < min_valid_error:
        min_valid_error = valid_loss
        min_valid_error_epoch = epoch_num
        save_params('model_base_2_best.pkl', model_base_2)
    
    print('|{:>4}|{:.4f}|{:.4f} ({:>4})|{:>4.1f}').format(
        epoch_num, valid_loss, min_valid_error, min_valid_error_epoch,
        time.time() - start_time
    )
    
# Finish training
save_valid_error('model_base_2_valid_error.pkl', valid_error)

set_params('./model_base_2_best.pkl', model_base_2)
test_loss = np.mean([test_model_base_2(i) for i in xrange(n_test_batches)])
print('Test error: {}'.format(test_loss))

pylab.rcParams['figure.figsize'] = 8, 6
plt.plot(valid_error)
plt.ylabel('valid error')
plt.xlabel('epoch #')
plt.title('model_base_2')
# Out:
# |Epoch|Valid error|Min (Epoch)|Sec/epoch
# |-:|-:|-:|-:
# |   1|0.3640|0.3640 (   1)|13.3
# |   2|0.3390|0.3390 (   2)|13.2
# |   3|0.3280|0.3280 (   3)|11.7
# |   4|0.3306|0.3280 (   3)|13.1
# |   5|0.3166|0.3166 (   5)|13.2
# |   6|0.3214|0.3166 (   5)|13.2
# |   7|0.3130|0.3130 (   7)|13.3
# |   8|0.3280|0.3130 (   7)|13.1
# |   9|0.3232|0.3130 (   7)|13.1
# |  10|0.3086|0.3086 (  10)|13.2
# |  11|0.3192|0.3086 (  10)|13.2
# |  12|0.3092|0.3086 (  10)|13.1
# |  13|0.3174|0.3086 (  10)|13.2
# |  14|0.3118|0.3086 (  10)|11.5
# |  15|0.3166|0.3086 (  10)|12.7
# |  16|0.3216|0.3086 (  10)|13.1
# |  17|0.3278|0.3086 (  10)|13.2
# |  18|0.3334|0.3086 (  10)|13.1
# |  19|0.3236|0.3086 (  10)|13.1
# |  20|0.3204|0.3086 (  10)|13.1
# |  21|0.3144|0.3086 (  10)|13.1
# |  22|0.3194|0.3086 (  10)|13.0
# |  23|0.3140|0.3086 (  10)|13.2
# |  24|0.3170|0.3086 (  10)|13.1
# |  25|0.3204|0.3086 (  10)|13.0
# |  26|0.3212|0.3086 (  10)|13.1
# |  27|0.3164|0.3086 (  10)|13.2
# |  28|0.3184|0.3086 (  10)|13.1
# |  29|0.3198|0.3086 (  10)|13.1
# |  30|0.3160|0.3086 (  10)|13.1
# |  31|0.3166|0.3086 (  10)|13.0
# |  32|0.3174|0.3086 (  10)|13.1
# |  33|0.3208|0.3086 (  10)|13.1
# |  34|0.3182|0.3086 (  10)|13.1
# |  35|0.3182|0.3086 (  10)|13.1
# |  36|0.3174|0.3086 (  10)|13.1
# |  37|0.3214|0.3086 (  10)|13.0
# |  38|0.3182|0.3086 (  10)|13.1
# |  39|0.3168|0.3086 (  10)|13.0
# |  40|0.3212|0.3086 (  10)|13.1
# |  41|0.3172|0.3086 (  10)|13.1
# |  42|0.3194|0.3086 (  10)|13.2
# |  43|0.3186|0.3086 (  10)|13.1
# |  44|0.3184|0.3086 (  10)|13.1
# |  45|0.3176|0.3086 (  10)|13.1
# |  46|0.3190|0.3086 (  10)|13.2
# |  47|0.3172|0.3086 (  10)|13.1
# |  48|0.3172|0.3086 (  10)|13.1
# |  49|0.3186|0.3086 (  10)|13.3
# |  50|0.3214|0.3086 (  10)|13.2
# |  51|0.3192|0.3086 (  10)|13.1
# |  52|0.3196|0.3086 (  10)|13.1
# |  53|0.3178|0.3086 (  10)|13.2
# |  54|0.3162|0.3086 (  10)|13.1
# |  55|0.3198|0.3086 (  10)|13.0
# |  56|0.3190|0.3086 (  10)|13.0
# |  57|0.3188|0.3086 (  10)|13.1
# |  58|0.3184|0.3086 (  10)|13.1
# |  59|0.3180|0.3086 (  10)|13.1
# |  60|0.3172|0.3086 (  10)|13.1
# |  61|0.3196|0.3086 (  10)|13.2
# |  62|0.3194|0.3086 (  10)|13.2
# |  63|0.3206|0.3086 (  10)|13.1
# |  64|0.3180|0.3086 (  10)|13.1
# |  65|0.3180|0.3086 (  10)|11.6
# |  66|0.3202|0.3086 (  10)|12.9
# |  67|0.3206|0.3086 (  10)|13.2
# |  68|0.3198|0.3086 (  10)|13.2
# |  69|0.3182|0.3086 (  10)|13.2
# |  70|0.3206|0.3086 (  10)|13.2
# |  71|0.3190|0.3086 (  10)|13.1
# |  72|0.3188|0.3086 (  10)|13.1
# |  73|0.3190|0.3086 (  10)|13.2
# |  74|0.3182|0.3086 (  10)|13.2
# |  75|0.3192|0.3086 (  10)|13.2
# |  76|0.3198|0.3086 (  10)|13.2
# |  77|0.3196|0.3086 (  10)|13.1
# |  78|0.3192|0.3086 (  10)|13.1
# |  79|0.3194|0.3086 (  10)|12.7
# |  80|0.3194|0.3086 (  10)|12.4
# |  81|0.3194|0.3086 (  10)|13.1
# |  82|0.3210|0.3086 (  10)|13.1
# |  83|0.3188|0.3086 (  10)|13.1
# |  84|0.3216|0.3086 (  10)|13.1
# |  85|0.3198|0.3086 (  10)|13.1
# |  86|0.3196|0.3086 (  10)|13.1
# |  87|0.3210|0.3086 (  10)|13.6
# |  88|0.3218|0.3086 (  10)|13.1
# |  89|0.3204|0.3086 (  10)|13.1
# |  90|0.3202|0.3086 (  10)|13.1
# |  91|0.3202|0.3086 (  10)|13.2
# |  92|0.3220|0.3086 (  10)|13.1
# |  93|0.3202|0.3086 (  10)|13.1
# |  94|0.3196|0.3086 (  10)|13.2
# |  95|0.3210|0.3086 (  10)|12.5
# |  96|0.3212|0.3086 (  10)|12.8
# |  97|0.3212|0.3086 (  10)|13.1
# |  98|0.3206|0.3086 (  10)|13.1
# |  99|0.3202|0.3086 (  10)|13.2
# | 100|0.3218|0.3086 (  10)|13.1
# Test error: 0.3274

# %% [markdown]
# **Base 3: Train using half of partition 1, half of partition 2**

# %%
print '... building model_base_3'

rng = numpy.random.RandomState(23455)
random.seed(51665)

model_base_3 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
    temperature=temperature
)

cost_model_base_3 = (
    model_base_3.negative_log_likelihood(y) + \
    L1_reg * model_base_3.L1 + \
    L2_reg * model_base_3.L2_sqr
)

test_model_base_3 = theano.function(
    inputs=[index],
    outputs=model_base_3.errors(y),
    givens={
        x: test_set_x[index * batch_size: (index + 1) * batch_size],
        y: test_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

validate_model_base_3 = theano.function(
    inputs=[index],
    outputs=model_base_3.errors(y),
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

grads_model_base_3 = [T.grad(cost_model_base_3, param) for param in model_base_3.params]

updates_model_base_3 = [
    (param, param - learning_rate * grad)
    for param, grad in zip(model_base_3.params, grads_model_base_3)
]

train_model_base_3 = theano.function(
    inputs=[index],
    outputs=cost_model_base_3,
    updates=updates_model_base_3,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)
# Out:
# ... building model_base_3

# %%
valid_error = []
min_valid_error = np.inf
min_valid_error_epoch = 0
minibatch_indexes = range(int(n_train_batches * 0.25), int(n_train_batches * 0.75))
epoch_num = 0
print('|Epoch|Valid error|Min (Epoch)|Sec/epoch')
print('|-:|-:|-:|-:')

while should_continue_training(min_valid_error_epoch, epoch_num):
    epoch_num += 1
    start_time = time.time()
    random.shuffle(minibatch_indexes)
    
    for minibatch_index in minibatch_indexes:
        train_model_base_3(minibatch_index)
        
    valid_loss = np.mean([validate_model_base_3(i) for i in xrange(n_valid_batches)])
    valid_error.append(valid_loss)
    
    if valid_loss < min_valid_error:
        min_valid_error = valid_loss
        min_valid_error_epoch = epoch_num
        save_params('model_base_3_best.pkl', model_base_3)
    
    print('|{:>4}|{:.4f}|{:.4f} ({:>4})|{:>4.1f}').format(
        epoch_num, valid_loss, min_valid_error, min_valid_error_epoch,
        time.time() - start_time
    )
    
# Finish training
save_valid_error('model_base_3_valid_error.pkl', valid_error)

set_params('./model_base_3_best.pkl', model_base_3)
test_loss = np.mean([test_model_base_3(i) for i in xrange(n_test_batches)])
print('Test error: {}'.format(test_loss))

pylab.rcParams['figure.figsize'] = 8, 6
plt.plot(valid_error)
plt.ylabel('valid error')
plt.xlabel('epoch #')
plt.title('model_base_3')
# Out:
# |Epoch|Valid error|Min (Epoch)|Sec/epoch
# |-:|-:|-:|-:
# |   1|0.5514|0.5514 (   1)|11.3
# |   2|0.4728|0.4728 (   2)|11.2
# |   3|0.4286|0.4286 (   3)|11.2
# |   4|0.3892|0.3892 (   4)|11.3
# |   5|0.3726|0.3726 (   5)|11.3
# |   6|0.3622|0.3622 (   6)|11.3
# |   7|0.3646|0.3622 (   6)|11.2
# |   8|0.3614|0.3614 (   8)|11.3
# |   9|0.3568|0.3568 (   9)|11.3
# |  10|0.3452|0.3452 (  10)|11.4
# |  11|0.3554|0.3452 (  10)|11.2
# |  12|0.3504|0.3452 (  10)|11.2
# |  13|0.3676|0.3452 (  10)|11.2
# |  14|0.3548|0.3452 (  10)|11.2
# |  15|0.3482|0.3452 (  10)|11.2
# |  16|0.3568|0.3452 (  10)|11.2
# |  17|0.3532|0.3452 (  10)|11.4
# |  18|0.3556|0.3452 (  10)|11.2
# |  19|0.3568|0.3452 (  10)|11.1
# |  20|0.3528|0.3452 (  10)|11.1
# |  21|0.3536|0.3452 (  10)|11.1
# |  22|0.3614|0.3452 (  10)|11.2
# |  23|0.3616|0.3452 (  10)|11.2
# |  24|0.3574|0.3452 (  10)|11.2
# |  25|0.3574|0.3452 (  10)|11.2
# |  26|0.3574|0.3452 (  10)|11.2
# |  27|0.3574|0.3452 (  10)|11.1
# |  28|0.3568|0.3452 (  10)|11.1
# |  29|0.3598|0.3452 (  10)|11.1
# |  30|0.3574|0.3452 (  10)|11.2
# |  31|0.3562|0.3452 (  10)|11.2
# |  32|0.3542|0.3452 (  10)|11.2
# |  33|0.3544|0.3452 (  10)|11.2
# |  34|0.3584|0.3452 (  10)|11.2
# |  35|0.3580|0.3452 (  10)|11.2
# |  36|0.3572|0.3452 (  10)|11.2
# |  37|0.3548|0.3452 (  10)|11.2
# |  38|0.3610|0.3452 (  10)|11.2
# |  39|0.3570|0.3452 (  10)|11.1
# |  40|0.3564|0.3452 (  10)|11.2
# |  41|0.3574|0.3452 (  10)|11.2
# |  42|0.3602|0.3452 (  10)|11.2
# |  43|0.3578|0.3452 (  10)|11.2
# |  44|0.3572|0.3452 (  10)|11.2
# |  45|0.3594|0.3452 (  10)|11.2
# |  46|0.3560|0.3452 (  10)|11.1
# |  47|0.3584|0.3452 (  10)|11.1
# |  48|0.3582|0.3452 (  10)|11.1
# |  49|0.3572|0.3452 (  10)|11.2
# |  50|0.3558|0.3452 (  10)|11.1
# |  51|0.3576|0.3452 (  10)|11.1
# |  52|0.3568|0.3452 (  10)|11.1
# |  53|0.3590|0.3452 (  10)|11.2
# |  54|0.3580|0.3452 (  10)|11.2
# |  55|0.3570|0.3452 (  10)|11.2
# |  56|0.3578|0.3452 (  10)|11.2
# |  57|0.3580|0.3452 (  10)|11.2
# |  58|0.3560|0.3452 (  10)|11.2
# |  59|0.3586|0.3452 (  10)|11.2
# |  60|0.3566|0.3452 (  10)|11.2
# |  61|0.3560|0.3452 (  10)|11.2
# |  62|0.3570|0.3452 (  10)|11.2
# |  63|0.3580|0.3452 (  10)|11.2
# |  64|0.3586|0.3452 (  10)|11.1
# |  65|0.3576|0.3452 (  10)|11.2
# |  66|0.3592|0.3452 (  10)|11.2
# |  67|0.3578|0.3452 (  10)|11.2
# |  68|0.3560|0.3452 (  10)|11.2
# |  69|0.3576|0.3452 (  10)|11.2
# |  70|0.3570|0.3452 (  10)|11.2
# |  71|0.3570|0.3452 (  10)|11.2
# |  72|0.3588|0.3452 (  10)|11.2
# |  73|0.3576|0.3452 (  10)|11.2
# |  74|0.3576|0.3452 (  10)|11.2
# |  75|0.3562|0.3452 (  10)|11.2
# |  76|0.3560|0.3452 (  10)|11.2
# |  77|0.3562|0.3452 (  10)|11.2
# |  78|0.3570|0.3452 (  10)|11.2
# |  79|0.3570|0.3452 (  10)|11.2
# |  80|0.3578|0.3452 (  10)|11.2
# |  81|0.3586|0.3452 (  10)|11.2
# |  82|0.3562|0.3452 (  10)|11.1
# |  83|0.3562|0.3452 (  10)|11.2
# |  84|0.3572|0.3452 (  10)|11.2
# |  85|0.3594|0.3452 (  10)|11.2
# |  86|0.3564|0.3452 (  10)|11.2
# |  87|0.3536|0.3452 (  10)|11.2
# |  88|0.3576|0.3452 (  10)|11.2
# |  89|0.3570|0.3452 (  10)|11.2
# |  90|0.3572|0.3452 (  10)|11.2
# |  91|0.3572|0.3452 (  10)|11.2
# |  92|0.3542|0.3452 (  10)|11.2
# |  93|0.3572|0.3452 (  10)|11.2
# |  94|0.3556|0.3452 (  10)|11.2
# |  95|0.3580|0.3452 (  10)|11.2
# |  96|0.3564|0.3452 (  10)|11.2
# |  97|0.3562|0.3452 (  10)|11.2
# |  98|0.3584|0.3452 (  10)|11.2
# |  99|0.3552|0.3452 (  10)|11.2
# | 100|0.3566|0.3452 (  10)|11.2
# Test error: 0.3586

# %% [markdown]
# **Base 4: Initialize with average of 2 models, train w/o KD**

# %%
print('Building model_average')
rng = numpy.random.RandomState(23455)
random.seed(51665)

model_1 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
)
set_params('./model_1_best.pkl', model_1)

model_2 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
)
set_params('./model_2_best.pkl', model_2)

model_merged = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
)
# Only apply to conv layer, First 4: hidden, logReg layer
set_avg_params(['model_1_best.pkl', 'model_2_best.pkl'], model_merged, layer_start=4)  

cost_model_merged = T.mean(
    model_merged.negative_log_likelihood(y) + 
    L1_reg * model_merged.L1 + 
    L2_reg * model_merged.L2_sqr
)

gparams_model_merged = (
    [T.grad(cost_model_merged, param) for param in model_merged.params]
)

validate_model_merged = theano.function(
    inputs=[index],
    outputs=model_merged.errors(y),
    givens={
        x: valid_set_x[index * batch_size:(index + 1) * batch_size],
        y: valid_set_y[index * batch_size:(index + 1) * batch_size]
    }
)

test_model_merged = theano.function(
    inputs=[index],
    outputs=model_merged.errors(y),
    givens={
        x: test_set_x[index * batch_size:(index + 1) * batch_size],
        y: test_set_y[index * batch_size:(index + 1) * batch_size]
    }
)

updates_model_merged = [
    (param, param - learning_rate * gparam)
    for param, gparam in zip(model_merged.params, gparams_model_merged)
]

train_model_merged = theano.function(
    inputs=[index],
    outputs=cost_model_merged,
    updates=updates_model_merged,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

# %%
valid_error = []
min_valid_error = np.inf
min_valid_error_epoch = 0
minibatch_indexes = range(int(n_train_batches * 0.25), int(n_train_batches * 0.75))
epoch_num = 0
print('|Epoch|Valid error|Min (Epoch)|Sec/epoch')
print('|-:|-:|-:|-:')

while should_continue_training(min_valid_error_epoch, epoch_num):
    epoch_num += 1
    start_time = time.time()
    random.shuffle(minibatch_indexes)
    
    for minibatch_index in minibatch_indexes:
        train_model_merged(minibatch_index)
        
    valid_loss = np.mean([validate_model_merged(i) for i in xrange(n_valid_batches)])
    valid_error.append(valid_loss)
    
    if valid_loss < min_valid_error:
        min_valid_error = valid_loss
        min_valid_error_epoch = epoch_num
        save_params('average_best.pkl', model_merged)
    
    print('|{:>4}|{:.4f}|{:.4f} ({:>4})|{:>4.1f}').format(
        epoch_num, valid_loss, min_valid_error, min_valid_error_epoch,
        time.time() - start_time
    )
    
# Finish training
save_valid_error('average.pkl', valid_error)

pylab.rcParams['figure.figsize'] = 8, 6
plt.plot(valid_error)
plt.ylabel('Valid error')
plt.xlabel('Epoch #')
plt.title('Model Merged')

set_params('./average_best.pkl', model_merged)
test_loss = np.mean([test_model_merged(i) for i in xrange(n_test_batches)])
print('Test error: {}'.format(test_loss))
# Out:
# |Epoch|Valid error|Min (Epoch)|Sec/epoch
# |-:|-:|-:|-:
# |   1|0.3738|0.3738 (   1)|11.3
# |   2|0.3452|0.3452 (   2)|11.3
# |   3|0.3302|0.3302 (   3)|11.5
# |   4|0.3180|0.3180 (   4)|11.3
# |   5|0.3188|0.3180 (   4)|11.2
# |   6|0.3144|0.3144 (   6)|11.2
# |   7|0.3208|0.3144 (   6)|11.2
# |   8|0.3232|0.3144 (   6)|11.2
# |   9|0.3200|0.3144 (   6)|11.2
# |  10|0.3154|0.3144 (   6)|11.2
# |  11|0.3214|0.3144 (   6)|11.2
# |  12|0.3208|0.3144 (   6)|11.2
# |  13|0.3426|0.3144 (   6)|11.2
# |  14|0.3214|0.3144 (   6)|11.2
# |  15|0.3232|0.3144 (   6)|11.2
# |  16|0.3228|0.3144 (   6)|11.2
# |  17|0.3290|0.3144 (   6)|11.2
# |  18|0.3248|0.3144 (   6)|11.2
# |  19|0.3280|0.3144 (   6)|11.3
# |  20|0.3316|0.3144 (   6)|11.2
# |  21|0.3320|0.3144 (   6)|11.2
# |  22|0.3262|0.3144 (   6)|11.2
# |  23|0.3276|0.3144 (   6)|11.2
# |  24|0.3264|0.3144 (   6)|11.2
# |  25|0.3274|0.3144 (   6)|11.2
# |  26|0.3292|0.3144 (   6)|11.2
# |  27|0.3288|0.3144 (   6)|11.2
# |  28|0.3236|0.3144 (   6)|11.2
# |  29|0.3268|0.3144 (   6)|11.2
# |  30|0.3260|0.3144 (   6)|11.2
# |  31|0.3254|0.3144 (   6)|11.2
# |  32|0.3242|0.3144 (   6)|11.3
# |  33|0.3250|0.3144 (   6)|11.2
# |  34|0.3238|0.3144 (   6)|11.2
# |  35|0.3256|0.3144 (   6)|11.2
# |  36|0.3242|0.3144 (   6)|11.2
# |  37|0.3234|0.3144 (   6)|11.2
# |  38|0.3234|0.3144 (   6)|11.2
# |  39|0.3268|0.3144 (   6)|11.2
# |  40|0.3266|0.3144 (   6)|11.2
# |  41|0.3246|0.3144 (   6)|11.2
# |  42|0.3250|0.3144 (   6)|11.2
# |  43|0.3238|0.3144 (   6)|11.2
# |  44|0.3230|0.3144 (   6)|11.2
# |  45|0.3246|0.3144 (   6)|11.2
# |  46|0.3260|0.3144 (   6)|11.3
# |  47|0.3234|0.3144 (   6)|11.2
# |  48|0.3240|0.3144 (   6)|11.2
# |  49|0.3250|0.3144 (   6)|11.2
# |  50|0.3236|0.3144 (   6)|11.2
# |  51|0.3236|0.3144 (   6)|11.2
# |  52|0.3246|0.3144 (   6)|11.2
# |  53|0.3240|0.3144 (   6)|11.2
# |  54|0.3264|0.3144 (   6)|11.2
# |  55|0.3256|0.3144 (   6)|11.2
# |  56|0.3246|0.3144 (   6)|11.2
# |  57|0.3254|0.3144 (   6)|11.2
# |  58|0.3252|0.3144 (   6)|11.2
# |  59|0.3254|0.3144 (   6)|11.2
# |  60|0.3264|0.3144 (   6)|11.2
# |  61|0.3254|0.3144 (   6)|11.2
# |  62|0.3244|0.3144 (   6)|11.2
# |  63|0.3258|0.3144 (   6)|11.2
# |  64|0.3270|0.3144 (   6)|11.2
# |  65|0.3258|0.3144 (   6)|11.2
# |  66|0.3260|0.3144 (   6)|11.2
# |  67|0.3246|0.3144 (   6)|11.2
# |  68|0.3258|0.3144 (   6)|11.2
# |  69|0.3250|0.3144 (   6)|11.2
# |  70|0.3260|0.3144 (   6)|11.2
# |  71|0.3238|0.3144 (   6)|11.2
# |  72|0.3266|0.3144 (   6)|11.2
# |  73|0.3248|0.3144 (   6)|11.3
# |  74|0.3258|0.3144 (   6)|11.2
# |  75|0.3252|0.3144 (   6)|11.2
# |  76|0.3254|0.3144 (   6)|11.2
# |  77|0.3252|0.3144 (   6)|11.2
# |  78|0.3260|0.3144 (   6)|11.2
# |  79|0.3252|0.3144 (   6)|11.2
# |  80|0.3252|0.3144 (   6)|11.2
# |  81|0.3250|0.3144 (   6)|11.2
# |  82|0.3246|0.3144 (   6)|11.2
# |  83|0.3248|0.3144 (   6)|11.2
# |  84|0.3246|0.3144 (   6)|11.2
# |  85|0.3268|0.3144 (   6)|11.2
# |  86|0.3240|0.3144 (   6)|11.2
# |  87|0.3238|0.3144 (   6)|11.2
# |  88|0.3254|0.3144 (   6)|11.3
# |  89|0.3248|0.3144 (   6)|11.2
# |  90|0.3248|0.3144 (   6)|11.2
# |  91|0.3256|0.3144 (   6)|11.2
# |  92|0.3266|0.3144 (   6)|11.2
# |  93|0.3244|0.3144 (   6)|11.2
# |  94|0.3230|0.3144 (   6)|11.2
# |  95|0.3234|0.3144 (   6)|11.2
# |  96|0.3258|0.3144 (   6)|11.2
# |  97|0.3268|0.3144 (   6)|11.2
# |  98|0.3240|0.3144 (   6)|11.2
# |  99|0.3250|0.3144 (   6)|11.2
# | 100|0.3256|0.3144 (   6)|11.2
# Test error: 0.329

# %% [markdown]
# **Combine 2 models into 1 $\rightarrow$ model_merged**

# %%
temperature = 4.08239746
lambda_teacher = 0.87121582

# %%
rng = numpy.random.RandomState(23455)
random.seed(51665)

model_1 = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
    temperature=temperature
)
set_params('./model_1_best.pkl', model_1)

model_merged = MLPConv(
    rng=rng,
    model_input=x,
    nkerns=nkerns, 
    n_in=n_in,
    temperature=temperature
)
# Only apply to conv layer, First 4: hidden, logReg layer
set_avg_params(['model_1_best.pkl'], model_merged, layer_start=4)  

cost_wrt_target = ( 
    -T.log(model_merged.p_y_given_x)[T.arange(y.shape[0]), y]
)

cost_wrt_teacher = (
    T.sum(-T.log(model_merged.p_y_given_x_relaxed) * model_1.p_y_given_x_relaxed,
          axis=1)
)

cost_model_merged = T.mean(
    (1 - lambda_teacher) * cost_wrt_target + lambda_teacher * cost_wrt_teacher
)

gparams_model_merged = (
    [T.grad(cost_model_merged, param) for param in model_merged.params]
)

validate_model_merged = theano.function(
    inputs=[index],
    outputs=model_merged.errors(y),
    givens={
        x: valid_set_x[index * batch_size:(index + 1) * batch_size],
        y: valid_set_y[index * batch_size:(index + 1) * batch_size]
    }
)

test_model_merged = theano.function(
    inputs=[index],
    outputs=model_merged.errors(y),
    givens={
        x: test_set_x[index * batch_size:(index + 1) * batch_size],
        y: test_set_y[index * batch_size:(index + 1) * batch_size]
    }
)

updates_model_merged = [
    (param, param - learning_rate * gparam)
    for param, gparam in zip(model_merged.params, gparams_model_merged)
]

train_model_merged = theano.function(
    inputs=[index],
    outputs=cost_model_merged,
    updates=updates_model_merged,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

# %%
valid_error = []
min_valid_error = np.inf
min_valid_error_epoch = 0
minibatch_indexes = range(int(n_train_batches * 0.50), int(n_train_batches * 1.00))
epoch_num = 0
print('|Epoch|Valid error|Min (Epoch)|Sec/epoch')
print('|-:|-:|-:|-:')

while should_continue_training(min_valid_error_epoch, epoch_num):
    epoch_num += 1
    start_time = time.time()
    random.shuffle(minibatch_indexes)
    
    for minibatch_index in minibatch_indexes:
        train_model_merged(minibatch_index)
        
    valid_loss = np.mean([validate_model_merged(i) for i in xrange(n_valid_batches)])
    valid_error.append(valid_loss)
    
    if valid_loss < min_valid_error:
        min_valid_error = valid_loss
        min_valid_error_epoch = epoch_num
        save_params('model_merged_best.pkl', model_merged)
    
    print('|{:>4}|{:.4f}|{:.4f} ({:>4})|{:>4.1f}').format(
        epoch_num, valid_loss, min_valid_error, min_valid_error_epoch,
        time.time() - start_time
    )
    
# Finish training
save_valid_error('model_merged_valid_error.pkl', valid_error)

pylab.rcParams['figure.figsize'] = 8, 6
plt.plot(valid_error)
plt.ylabel('Valid error')
plt.xlabel('Epoch #')
plt.title('Model Merged')

set_params('./model_merged_best.pkl', model_merged)
test_loss = np.mean([test_model_merged(i) for i in xrange(n_test_batches)])
print('Test error: {}'.format(test_loss))
# Out:
# |Epoch|Valid error|Min (Epoch)|Sec/epoch
# |-:|-:|-:|-:
# |   1|0.4540|0.4540 (   1)|19.3
# |   2|0.4202|0.4202 (   2)|19.3
# |   3|0.3998|0.3998 (   3)|19.4
# |   4|0.3870|0.3870 (   4)|19.4
# |   5|0.3702|0.3702 (   5)|19.4
# |   6|0.3562|0.3562 (   6)|19.3
# |   7|0.3468|0.3468 (   7)|19.4
# |   8|0.3438|0.3438 (   8)|19.4
# |   9|0.3378|0.3378 (   9)|19.2
# |  10|0.3350|0.3350 (  10)|19.4
# |  11|0.3270|0.3270 (  11)|19.3
# |  12|0.3264|0.3264 (  12)|19.1
# |  13|0.3208|0.3208 (  13)|19.3
# |  14|0.3194|0.3194 (  14)|19.3
# |  15|0.3186|0.3186 (  15)|19.2
# |  16|0.3170|0.3170 (  16)|19.4
# |  17|0.3184|0.3170 (  16)|19.2
# |  18|0.3108|0.3108 (  18)|19.2
# |  19|0.3142|0.3108 (  18)|19.1
# |  20|0.3086|0.3086 (  20)|19.4
# |  21|0.3154|0.3086 (  20)|19.2
# |  22|0.3126|0.3086 (  20)|19.1
# |  23|0.3080|0.3080 (  23)|19.3
# |  24|0.3114|0.3080 (  23)|19.1
# |  25|0.3062|0.3062 (  25)|19.2
# |  26|0.3078|0.3062 (  25)|19.2
# |  27|0.3058|0.3058 (  27)|19.3
# |  28|0.3054|0.3054 (  28)|19.2
# |  29|0.3046|0.3046 (  29)|19.4
# |  30|0.3044|0.3044 (  30)|19.5
# |  31|0.3050|0.3044 (  30)|19.2
# |  32|0.3020|0.3020 (  32)|19.5
# |  33|0.3026|0.3020 (  32)|19.3
# |  34|0.3030|0.3020 (  32)|19.4
# |  35|0.3024|0.3020 (  32)|19.2
# |  36|0.2994|0.2994 (  36)|19.3
# |  37|0.3014|0.2994 (  36)|19.2
# |  38|0.3000|0.2994 (  36)|19.1
# |  39|0.2980|0.2980 (  39)|19.2
# |  40|0.2998|0.2980 (  39)|19.2
# |  41|0.2970|0.2970 (  41)|19.2
# |  42|0.2990|0.2970 (  41)|19.2
# |  43|0.2966|0.2966 (  43)|19.3
# |  44|0.2984|0.2966 (  43)|19.2
# |  45|0.2954|0.2954 (  45)|19.5
# |  46|0.2976|0.2954 (  45)|19.1
# |  47|0.2974|0.2954 (  45)|19.1
# |  48|0.2984|0.2954 (  45)|19.1
# |  49|0.2958|0.2954 (  45)|16.5
# |  50|0.2956|0.2954 (  45)|15.9
# |  51|0.2970|0.2954 (  45)|15.9
# |  52|0.2972|0.2954 (  45)|15.9
# |  53|0.2976|0.2954 (  45)|16.0
# |  54|0.2962|0.2954 (  45)|16.0
# |  55|0.2976|0.2954 (  45)|16.1
# |  56|0.2984|0.2954 (  45)|16.0
# |  57|0.2992|0.2954 (  45)|15.9
# |  58|0.2972|0.2954 (  45)|15.9
# |  59|0.2974|0.2954 (  45)|16.0
# |  60|0.2960|0.2954 (  45)|15.9
# |  61|0.2960|0.2954 (  45)|15.8
# |  62|0.2956|0.2954 (  45)|15.9
# |  63|0.2964|0.2954 (  45)|15.9
# |  64|0.2990|0.2954 (  45)|16.0
# |  65|0.3000|0.2954 (  45)|16.1
# |  66|0.2956|0.2954 (  45)|16.0
# |  67|0.2978|0.2954 (  45)|16.0
# |  68|0.2986|0.2954 (  45)|16.0
# |  69|0.2996|0.2954 (  45)|15.9
# |  70|0.2970|0.2954 (  45)|16.0
# |  71|0.2964|0.2954 (  45)|15.9
# |  72|0.2966|0.2954 (  45)|15.8
# |  73|0.3012|0.2954 (  45)|16.0
# |  74|0.2974|0.2954 (  45)|15.9
# |  75|0.2996|0.2954 (  45)|16.0
# |  76|0.2984|0.2954 (  45)|16.1
# |  77|0.2988|0.2954 (  45)|16.0
# |  78|0.2994|0.2954 (  45)|15.8
# |  79|0.2972|0.2954 (  45)|15.8
# |  80|0.2990|0.2954 (  45)|15.8
# |  81|0.2980|0.2954 (  45)|15.8
# |  82|0.3014|0.2954 (  45)|15.9
# |  83|0.2988|0.2954 (  45)|15.9
# |  84|0.2990|0.2954 (  45)|15.9
# |  85|0.2978|0.2954 (  45)|15.8
# |  86|0.3010|0.2954 (  45)|15.9
# |  87|0.3022|0.2954 (  45)|15.8
# |  88|0.3006|0.2954 (  45)|15.9
# |  89|0.2998|0.2954 (  45)|15.9
# |  90|0.2986|0.2954 (  45)|15.9
# |  91|0.3004|0.2954 (  45)|16.1
# |  92|0.3002|0.2954 (  45)|16.0
# |  93|0.3024|0.2954 (  45)|16.1
# |  94|0.3018|0.2954 (  45)|15.9
# |  95|0.3026|0.2954 (  45)|15.9
# |  96|0.3016|0.2954 (  45)|15.9
# |  97|0.3006|0.2954 (  45)|15.9
# |  98|0.3034|0.2954 (  45)|16.0
# |  99|0.3014|0.2954 (  45)|16.0
# | 100|0.3000|0.2954 (  45)|15.8
# Test error: 0.3102

# %%
def plot(file_paths):
    for file_path in file_paths:
        with open(file_path) as in_file:
            valid_error = cPickle.load(in_file)
            plt.plot(valid_error, label=os.path.basename(file_path))
    plt.ylabel('valid error')
    plt.xlabel('epoch')
    plt.legend()

# %%
valid_error_files = [
'no_split.pkl', 'split.pkl', 'average.pkl', 'step.pkl', 'step_kd.pkl'
]
pylab.rcParams['figure.figsize'] = 14, 9
pylab.rcParams['font.size'] = 17
plot(valid_error_files)
